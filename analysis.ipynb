# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
with open('output/yiqana1a_expert_loads.pkl', 'rb') as f:
    expert_load = pickle.load(f)

num_experts = 3
num_graphs = 3

# %%
# Total load
df = expert_load['total']

fig, ax = plt.subplots(figsize=(14, 8))
df.plot(kind='bar', stacked=True, ax=ax, width=1.0, edgecolor='none')

# Customize the plot
ax.set_xlabel('Iteration')
ax.set_ylabel('Expert Activations')
ax.set_title('Total load')
plt.legend(title='Expert', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_xticks(range(0, len(df), 20))  # Show only every 20th tick
ax.set_xticklabels(df.index[::20], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Graph 0
df0 = expert_load[0]

fig, ax = plt.subplots(figsize=(14, 8))
df0.plot(kind='bar', stacked=True, ax=ax, width=1.0, edgecolor='none')

# Customize the plot
ax.set_xlabel('Iteration')
ax.set_ylabel('Expert Activations')
ax.set_title('Graph 0')
plt.legend(title='Expert', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_xticks(range(0, len(df0), 20))  # Show only every 20th tick
ax.set_xticklabels(df0.index[::20], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Graph 1
df1 = expert_load[1]

fig, ax = plt.subplots(figsize=(14, 8))
df1.plot(kind='bar', stacked=True, ax=ax, width=1.0, edgecolor='none')

# Customize the plot
ax.set_xlabel('Iteration')
ax.set_ylabel('Expert Activations')
ax.set_title('Graph 1')
plt.legend(title='Expert', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_xticks(range(0, len(df1), 20))  # Show only every 20th tick
ax.set_xticklabels(df1.index[::20], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Graph 2
df2 = expert_load[2]

fig, ax = plt.subplots(figsize=(14, 8))
df2.plot(kind='bar', stacked=True, ax=ax, width=1.0, edgecolor='none')

# Customize the plot
ax.set_xlabel('Iteration')
ax.set_ylabel('Expert Activations')
ax.set_title('Graph 2')
plt.legend(title='Expert', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_xticks(range(0, len(df2), 20))  # Show only every 20th tick
ax.set_xticklabels(df2.index[::20], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Plots for each expert

# %%
df_exp0 = pd.DataFrame({i: expert_load[i]['exp0'] for i in range(num_experts)})

fig, ax = plt.subplots(figsize=(14, 8))
df_exp0.plot(kind='bar', stacked=True, ax=ax, width=1.0, edgecolor='none')

# Customize the plot
ax.set_xlabel('Iteration')
ax.set_ylabel('Graph Activations')
ax.set_title('Expert 0')
plt.legend(title='Graph', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_xticks(range(0, len(df2), 20))  # Show only every 20th tick
ax.set_xticklabels(df_exp0.index[::20], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df_exp1 = pd.DataFrame({i: expert_load[i]['exp1'] for i in range(num_experts)})

fig, ax = plt.subplots(figsize=(14, 8))
df_exp1.plot(kind='bar', stacked=True, ax=ax, width=1.0, edgecolor='none')

# Customize the plot
ax.set_xlabel('Iteration')
ax.set_ylabel('Graph Activations')
ax.set_title('Expert 1')
plt.legend(title='Graph', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_xticks(range(0, len(df2), 20))  # Show only every 20th tick
ax.set_xticklabels(df_exp1.index[::20], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df_exp2 = pd.DataFrame({i: expert_load[i]['exp2'] for i in range(num_experts)})

fig, ax = plt.subplots(figsize=(14, 8))
df_exp2.plot(kind='bar', stacked=True, ax=ax, width=1.0, edgecolor='none')

# Customize the plot
ax.set_xlabel('Iteration')
ax.set_ylabel('Graph Activations')
ax.set_title('Expert 2')
plt.legend(title='Graph', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_xticks(range(0, len(df_exp2), 20))  # Show only every 20th tick
ax.set_xticklabels(df_exp2.index[::20], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
